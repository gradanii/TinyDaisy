# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from tokenizer.tokenizer import BPETokenizer

# %%
class Embedding:
    def __init__(self, num_embed=512, embed_dim=768):
        self.tokenizer = BPETokenizer()
        self.vec_matrix = np.random.randn(num_embed, embed_dim)
        self.pos_matrix = np.random.randn(num_embed, embed_dim)

    def vector(self, list_of_strings):
        batch = []
        lengths = []
        tokens = [self.tokenizer.encode(s) for s in list_of_strings]
        max_len = max(len(t) for t in tokens)
        for token in tokens:
            padded = np.pad(token, (0, max_len - len(token)), constant_values=0)
            embedding = self.vec_matrix[padded]
            batch.append(embedding)
            lengths.append(len(token))

        return np.stack(batch), lengths

    def positional(self, lengths):
        batch = []
        max_len = max(lengths)
        for seq_len in lengths:
            pos_array = np.array([i for i in range(seq_len)], dtype=np.int64)
            padded = np.pad(pos_array, (0, max_len - seq_len), constant_values=0)
            pos_embed = self.pos_matrix[padded]
            batch.append(pos_embed)

        return np.stack(batch)

    def forward(self, list_of_strings):
        vec_embed, seq_len = self.vector(list_of_strings)
        pos_embed = self.positional(seq_len)
        embedding = vec_embed + pos_embed

        return embedding

# %%
import numpy as np

embed = Embedding()

embed.forward([
    "The sun is bright.",
    "Hello world!",
    "AI is transforming the world.",
    "Short"
])
# Out:
# array([[[-0.67289758, -0.65876184, -1.16885848, ..., -0.14573598,
#           1.53256203, -0.98027233],
#         [ 0.70515587, -0.60343866, -1.57071777, ...,  0.87306986,
#          -1.5945032 , -1.39735547],
#         [ 1.30462285, -1.70272355,  0.61659251, ..., -2.36780905,
#          -1.72164236, -0.30326686],
#         ...,
#         [-1.8928477 , -1.7798639 , -1.33986841, ...,  0.23387694,
#           0.18005925,  0.57449301],
#         [-1.8928477 , -1.7798639 , -1.33986841, ...,  0.23387694,
#           0.18005925,  0.57449301],
#         [-1.8928477 , -1.7798639 , -1.33986841, ...,  0.23387694,
#           0.18005925,  0.57449301]],
#
#        [[-1.56446585, -1.05304898, -1.35402063, ...,  1.0427826 ,
#          -0.95605947, -0.07663333],
#         [ 0.0812989 , -0.99898133, -1.32176596, ..., -0.62964367,
#          -1.73148353, -0.68579836],
#         [ 1.40792434, -1.54112876,  2.67011315, ..., -0.21924224,
#          -0.10274299,  0.01540285],
#         ...,
#         [-1.8928477 , -1.7798639 , -1.33986841, ...,  0.23387694,
#           0.18005925,  0.57449301],
#         [-1.8928477 , -1.7798639 , -1.33986841, ...,  0.23387694,
#           0.18005925,  0.57449301],
#         [-1.8928477 , -1.7798639 , -1.33986841, ...,  0.23387694,
#           0.18005925,  0.57449301]],
#
#        [[-1.44673134,  0.13492267, -1.46595059, ...,  0.9636235 ,
#          -0.02380201, -1.74320852],
#         [ 1.28005028,  0.10505127, -0.47045735, ..., -0.44860128,
#          -1.15684746,  0.34967254],
#         [ 1.19685439, -1.13005397,  1.13611306, ..., -0.96777107,
#           0.2608588 , -0.66030528],
#         ...,
#         [-1.30624499, -2.43640194,  2.39866435, ...,  1.43651612,
#          -1.05773071,  0.64010732],
#         [-0.42599513,  2.01909396, -1.17121017, ...,  2.80691597,
#          -0.06783724, -0.41435565],
#         [-2.02915708,  1.97510566, -0.46406109, ...,  1.31219738,
#           1.89938266, -1.24965313]],
#
#        [[ 1.58352921, -1.48779532, -2.48440855, ...,  2.13852792,
#          -0.88182808, -0.70790723],
#         [ 0.70515587, -0.60343866, -1.57071777, ...,  0.87306986,
#          -1.5945032 , -1.39735547],
#         [ 0.47840647, -0.90336358,  0.42004945, ..., -1.87257396,
#          -1.15924143, -1.20547566],
#         ...,
#         [-1.8928477 , -1.7798639 , -1.33986841, ...,  0.23387694,
#           0.18005925,  0.57449301],
#         [-1.8928477 , -1.7798639 , -1.33986841, ...,  0.23387694,
#           0.18005925,  0.57449301],
#         [-1.8928477 , -1.7798639 , -1.33986841, ...,  0.23387694,
#           0.18005925,  0.57449301]]], shape=(4, 29, 768))

# %%
class Attention:
    def __init__(self, embed_dim=768, head_dim=64, num_head=12):
        self.embed_dim = embed_dim
        self.head_dim = head_dim
        self.num_head = num_head
        self.w_q = [
            np.random.randn(self.embed_dim, self.head_dim) for _ in range(self.num_head)
        ]
        self.w_k = [
            np.random.randn(self.embed_dim, self.head_dim) for _ in range(self.num_head)
        ]
        self.w_v = [
            np.random.randn(self.embed_dim, self.head_dim) for _ in range(self.num_head)
        ]
        self.w_o = np.random.randn(self.head_dim * self.num_head, self.embed_dim)
        self.embed = Embedding()

    @staticmethod
    def softmax(x, axis=-1):
        exp_x = np.exp(x - np.max(x, axis=axis, keepdims=True))
        return exp_x / np.sum(exp_x, axis=axis, keepdims=True)

    def sdpa(self, q, k, v):
        scores = np.matmul(q, np.swapaxes(k, -2, -1))
        scaled_scores = scores / np.sqrt(self.head_dim)

        d_m = scaled_scores.shape[1]
        mask = np.triu(np.ones((d_m, d_m)) * -np.inf, k=1)
        mask = mask[np.newaxis, :, :]
        masked_scores = scaled_scores + mask

        a = self.softmax(masked_scores)
        z = np.matmul(a, v)

        return z
 
    def MultiHead(self, list_of_strings):
        x = self.embed.forward(list_of_strings)

        heads = []
        for i in range(self.num_head):
            query = np.matmul(x, self.w_q[i])
            key = np.matmul(x, self.w_k[i])
            value = np.matmul(x, self.w_v[i])

            z_i = self.sdpa(query, key, value)
            heads.append(z_i)

        concat = np.concatenate(heads, axis=-1)
        output = np.matmul(concat, self.w_o)

        return output

# %%
attention = Attention()

input = [
    "The sun is bright.",
    "Hello world!",
    "AI is transforming the world.",
    "Short"
]

attention.MultiHead(input)
# Out:
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:42: RuntimeWarning: divide by zero encountered in matmul
#   query = np.matmul(x, self.w_q[i])
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:42: RuntimeWarning: overflow encountered in matmul
#   query = np.matmul(x, self.w_q[i])
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:42: RuntimeWarning: invalid value encountered in matmul
#   query = np.matmul(x, self.w_q[i])
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:43: RuntimeWarning: divide by zero encountered in matmul
#   key = np.matmul(x, self.w_k[i])
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:43: RuntimeWarning: overflow encountered in matmul
#   key = np.matmul(x, self.w_k[i])
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:43: RuntimeWarning: invalid value encountered in matmul
#   key = np.matmul(x, self.w_k[i])
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:44: RuntimeWarning: divide by zero encountered in matmul
#   value = np.matmul(x, self.w_v[i])
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:44: RuntimeWarning: overflow encountered in matmul
#   value = np.matmul(x, self.w_v[i])
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:44: RuntimeWarning: invalid value encountered in matmul
#   value = np.matmul(x, self.w_v[i])
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:24: RuntimeWarning: divide by zero encountered in matmul
#   scores = np.matmul(q, np.swapaxes(k, -2, -1))
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:24: RuntimeWarning: overflow encountered in matmul
#   scores = np.matmul(q, np.swapaxes(k, -2, -1))
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:24: RuntimeWarning: invalid value encountered in matmul
#   scores = np.matmul(q, np.swapaxes(k, -2, -1))
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:33: RuntimeWarning: divide by zero encountered in matmul
#   z = np.matmul(a, v)
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:33: RuntimeWarning: overflow encountered in matmul
#   z = np.matmul(a, v)
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:33: RuntimeWarning: invalid value encountered in matmul
#   z = np.matmul(a, v)
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:50: RuntimeWarning: divide by zero encountered in matmul
#   output = np.matmul(concat, self.w_o)
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:50: RuntimeWarning: overflow encountered in matmul
#   output = np.matmul(concat, self.w_o)
# /var/folders/n1/57h339gs5nv64npf4zbyx7100000gn/T/ipykernel_1124/2301313760.py:50: RuntimeWarning: invalid value encountered in matmul
#   output = np.matmul(concat, self.w_o)
# array([[[ 8.76981741e+02, -3.76012659e+02,  5.74969991e+02, ...,
#          -3.77158841e+02, -3.38260857e+01, -4.33874268e+02],
#         [ 2.87835573e+02, -7.70914279e+02, -4.00145085e+02, ...,
#           8.37603895e+02,  7.08407259e+02,  9.95718250e+02],
#         [ 1.13469171e+03, -1.57253042e+03,  1.29967458e+03, ...,
#           8.15974310e+02, -1.57962632e+02,  3.99832623e+02],
#         ...,
#         [ 1.28590369e+03, -3.01137607e+02, -4.06931925e+02, ...,
#          -1.46399214e+03, -7.86071001e+02, -1.76032089e+03],
#         [ 1.28590369e+03, -3.01137607e+02, -4.06931925e+02, ...,
#          -1.46399214e+03, -7.86071001e+02, -1.76032089e+03],
#         [ 1.28590369e+03, -3.01137607e+02, -4.06931925e+02, ...,
#          -1.46399214e+03, -7.86071001e+02, -1.76032089e+03]],
#
#        [[ 3.13004882e+02,  3.91440123e+02,  1.21314096e+03, ...,
#          -3.23846965e+02,  6.09130755e+02,  5.78467781e+01],
#         [ 8.39614271e+02, -8.80535325e+02, -5.80785279e+02, ...,
#          -2.76071634e+02,  1.03998787e+03, -1.98493736e+02],
#         [ 5.50284161e+02, -7.23515450e+02,  7.54463539e+02, ...,
#           9.85817120e+02, -9.46000953e+02,  6.09245604e+02],
#         ...,
#         [ 7.26313035e+02,  1.33744210e+03,  1.54413322e+03, ...,
#           2.76781356e+02,  1.26052057e+03, -8.51929875e+02],
#         [ 7.26313035e+02,  1.33744210e+03,  1.54413322e+03, ...,
#           2.76781356e+02,  1.26052057e+03, -8.51929875e+02],
#         [ 7.26313035e+02,  1.33744210e+03,  1.54413322e+03, ...,
#           2.76781356e+02,  1.26052057e+03, -8.51929875e+02]],
#
#        [[-1.65998302e+02,  2.34530247e+02, -5.48869327e+02, ...,
#           3.92007305e+02,  6.68080758e+02,  1.35671189e+03],
#         [ 4.73169623e+02,  5.28276660e+02,  3.35599988e+01, ...,
#           1.12003216e+03, -1.91262790e+02,  2.94915754e+03],
#         [ 6.35203378e+02,  1.24957162e+01,  1.30699705e+03, ...,
#           9.97378254e+02,  1.79615075e+03,  3.10480867e+03],
#         ...,
#         [-7.04444610e-01, -1.01789453e+03, -2.01331346e+02, ...,
#          -1.60790044e+03, -1.14776400e+03,  1.65570309e+03],
#         [-3.03553707e+02, -7.88959201e+02,  2.77299485e+02, ...,
#          -1.48770804e+03, -3.86727693e+02,  7.35783407e+02],
#         [-1.71510215e+02, -1.18442895e+03, -1.10775932e+02, ...,
#          -9.01971646e+02, -1.31069017e+03, -1.66533217e+03]],
#
#        [[-2.73266611e+01,  4.02553336e+02, -3.88861139e+02, ...,
#          -3.96180994e+02,  1.63563444e+03, -2.75755957e+02],
#         [ 4.24889890e+02, -8.52323854e+02, -4.00063669e+02, ...,
#           6.02728420e+02,  4.87652387e+02,  7.65135276e+02],
#         [ 1.47501170e+03,  1.58577177e+03,  9.88808776e+02, ...,
#          -1.72932797e+02,  8.54194697e+02,  1.57609458e+03],
#         ...,
#         [-1.50447739e+02, -7.14448279e+02,  4.00337647e+02, ...,
#          -1.77660219e+03,  1.91301967e+03,  7.65389577e+02],
#         [-1.50447739e+02, -7.14448279e+02,  4.00337647e+02, ...,
#          -1.77660219e+03,  1.91301967e+03,  7.65389577e+02],
#         [-1.50447739e+02, -7.14448279e+02,  4.00337647e+02, ...,
#          -1.77660219e+03,  1.91301967e+03,  7.65389577e+02]]],
#       shape=(4, 29, 768))
